# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/127t6937/Keras-GAN/blob/master/Untitled34.ipynb)

# %%
# chainerセットアップ
# https://qiita.com/keisuke-umezawa/items/4e99c2a4f5f07567444c

# Install Chainer and CuPy!

# !apt -y install libcusparse8.0 libnvrtc8.0 libnvtoolsext1
# !ln -snf /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so.8.0 /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so
# !pip install https://github.com/kmaehashi/chainer-colab/releases/download/2018-02-06/cupy_cuda80-4.0.0b3-cp36-cp36m-linux_x86_64.whl
# !pip install 'chainer==4.0.0b3'
# !apt-get install graphviz
# !pip install 'chaineripy'
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libcusparse8.0 libnvrtc8.0 libnvtoolsext1
# 0 upgraded, 3 newly installed, 0 to remove and 0 not upgraded.
# Need to get 28.9 MB of archives.
# After this operation, 71.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 libcusparse8.0 amd64 8.0.61-1 [22.6 MB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 libnvrtc8.0 amd64 8.0.61-1 [6,225 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 libnvtoolsext1 amd64 8.0.61-1 [32.2 kB]
# Fetched 28.9 MB in 7s (3,923 kB/s)
# Selecting previously unselected package libcusparse8.0:amd64.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../libcusparse8.0_8.0.61-1_amd64.deb ...
# Unpacking libcusparse8.0:amd64 (8.0.61-1) ...
# ...

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

# chainer
import numpy as np
import chainer
from chainer import training
from chainer import iterators, optimizers, serializers
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions
from chainer.datasets import split_dataset
import pandas as pd
pd.options.display.precision = 3      # pandasの有効桁数を指定
print('GPU availability:', chainer.cuda.available)
print('cuDNN availablility:', chainer.cuda.cudnn_enabled)
# Out:
# GPU availability: True
# cuDNN availablility: True

# %%
# !git clone https://github.com/127t6937/chainer-gan-lib.git
# Out:
# Cloning into 'chainer-gan-lib'...
# remote: Counting objects: 193, done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 193 (delta 0), reused 0 (delta 0), pack-reused 190
# Receiving objects: 100% (193/193), 71.22 MiB | 56.45 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
# Out:
# command.txt               log                  SNDCGANDiscriminator_10000.npz
# DCGANGenerator_10000.npz  preview/             SNDCGANDiscriminator_1000.npz
# DCGANGenerator_1000.npz   snapshot_iter_1000   SNDCGANDiscriminator_11000.npz
# DCGANGenerator_11000.npz  snapshot_iter_10000  SNDCGANDiscriminator_2000.npz
# DCGANGenerator_2000.npz   snapshot_iter_11000  SNDCGANDiscriminator_3000.npz
# DCGANGenerator_3000.npz   snapshot_iter_2000   SNDCGANDiscriminator_4000.npz
# DCGANGenerator_4000.npz   snapshot_iter_3000   SNDCGANDiscriminator_5000.npz
# DCGANGenerator_5000.npz   snapshot_iter_4000   SNDCGANDiscriminator_6000.npz
# DCGANGenerator_6000.npz   snapshot_iter_5000   SNDCGANDiscriminator_7000.npz
# DCGANGenerator_7000.npz   snapshot_iter_6000   SNDCGANDiscriminator_8000.npz
# DCGANGenerator_8000.npz   snapshot_iter_7000   SNDCGANDiscriminator_9000.npz
# DCGANGenerator_9000.npz   snapshot_iter_8000   train.py
# __init__.py               snapshot_iter_9000

# %%
# !python train.py --gpu 0 --algorithm cramer --architecture sndcgan --out result_sncramer --adam_alpha 0.0001 --adam_beta1 0.5 --adam_beta2 0.999 --output_dim 256 --n_dis 1
# Out:
# /usr/local/lib/python3.6/dist-packages/cupy/core/fusion.py:659: FutureWarning: cupy.core.fusion is experimental. The interface can change in the future.
#   util.experimental('cupy.core.fusion')
# load cifar-10.  shape:  (50000, 3, 32, 32)
# use gpu 0
# loss_dis    loss_gen    inception_mean  inception_std  FID         loss_gp
# 103.341     223.106
# 38.3037     317.521
# 5.51364     223.415
# 27.1925     413.001
# 192.44      577.671
# 45.7345     406.059
# 3.05068     124.779
# 45.3553     282.51
# 38.5907     213.505
# 4.48943     85.8456
# 28.0814     79.1359
# 27.2384     153.978
# 49.2159     145.159
# 96.868      400.541
# 144.307     481.564
# 185.265     864.157
# 129.281     639.773
# 118.105     594.153
# 105.971     810.514
# 104.822     376.173
# 143.763     649.474
# 143.4       456.115
# 97.4776     529.746
# 101.556     476.288
# 75.0901     469.763
# 55.9998     306.477
# 35.0267     321.884
# 67.9967     187.655
# 67.0668     238.438
# 35.0745     131.953
# ...
